# %%
import matplotlib.pyplot as plt

# %matplotlib inline
import numpy as np

# %%
countries = ["USA", "GB", "China", "Russia", "Germany"]
bronzes = np.array([38, 17, 26, 19, 15])
silvers = np.array([37, 23, 18, 17, 10])
golds = np.array([46, 27, 26, 19, 17])
total = np.array([121, 67, 70, 55, 42])

# %%
plt.bar(x_cor, total, color="green", edgecolor="black")
plt.xticks(x_cor, countries)
plt.ylabel("Medals")
plt.xlabel("Countries")
plt.title("2016 Olympic Medals: Top Countries")
plt.show()

# %%
plt.bar(x_cor, bronzes, color="#CD853F", edgecolor="black", label="bronze medals")
plt.bar(x_cor, silvers, color="silver", bottom=bronzes, edgecolor="black", label="silver medals")
plt.bar(x_cor, golds, color="gold", bottom=silvers + bronzes, edgecolor="black", label="gold medals")
plt.xticks(x_cor, countries)
plt.ylabel("Medals")
plt.xlabel("Countries")
plt.title("2016 Olympic Medals: Top Countries")
plt.legend(loc="upper right")
plt.show()
